# %% [markdown]
# Git clone the repo and install the requirements. (ignore the pip errors about protobuf)

# %%
#@title Environment Setup

from pathlib import Path

OPTIONS = {}

USE_GOOGLE_DRIVE = True  #@param {type:"boolean"}
UPDATE_COMFY_UI = True  #@param {type:"boolean"}
WORKSPACE = 'ComfyUI'
OPTIONS['USE_GOOGLE_DRIVE'] = USE_GOOGLE_DRIVE
OPTIONS['UPDATE_COMFY_UI'] = UPDATE_COMFY_UI

if OPTIONS['USE_GOOGLE_DRIVE']:
    # !echo "Mounting Google Drive..."
    # %cd /

    from google.colab import drive
    drive.mount('/content/drive')

    WORKSPACE = "/content/drive/MyDrive/ComfyUI"
    # %cd /content/drive/MyDrive

![ ! -d $WORKSPACE ] && echo -= Initial setup ComfyUI =- && git clone https://github.com/comfyanonymous/ComfyUI
# %cd $WORKSPACE

if OPTIONS['UPDATE_COMFY_UI']:
  # !echo -= Updating ComfyUI =-
  # !git pull

# !echo -= Install dependencies =-
# !pip install xformers!=0.0.18 -r requirements.txt --extra-index-url https://download.pytorch.org/whl/cu121 --extra-index-url https://download.pytorch.org/whl/cu118 --extra-index-url https://download.pytorch.org/whl/cu117
# Out:
# Mounting Google Drive...
# /
# Mounted at /content/drive
# /content/drive/MyDrive
# -= Initial setup ComfyUI =-
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 35555, done.
# remote: Counting objects: 100% (188/188), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 35555 (delta 134), reused 73 (delta 68), pack-reused 35367 (from 3)
# Receiving objects: 100% (35555/35555), 84.15 MiB | 12.64 MiB/s, done.
# Resolving deltas: 100% (24093/24093), done.
# Updating files: 100% (772/772), done.
# /content/drive/MyDrive/ComfyUI
# -= Updating ComfyUI =-
# Already up to date.
# -= Install dependencies =-
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121, https://download.pytorch.org/whl/cu118, https://download.pytorch.org/whl/cu117
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.9/21.9 MB 48.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 62.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# Download some models/checkpoints/vae or custom comfyui nodes (uncomment the commands for the ones you want)

# %%
# ============================================================
# PASO 1 - CUSTOM NODES ESENCIALES
# ============================================================

import os
os.chdir('/content/ComfyUI')

# AnimateDiff Evolved - videos con SD1.5 y SDXL
# !cd custom_nodes && git clone https://github.com/Kosinkadink/ComfyUI-AnimateDiff-Evolved.git

# Video Helper Suite - exportar videos
# !cd custom_nodes && git clone https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite.git

# Advanced ControlNet
# !cd custom_nodes && git clone https://github.com/Kosinkadink/ComfyUI-Advanced-ControlNet.git

# IPAdapter Plus - transferencia de cara/estilo desde imagen
# !cd custom_nodes && git clone https://github.com/cubiq/ComfyUI_IPAdapter_plus.git

# ControlNet Preprocessors - Canny, Depth, Pose, etc.
# !cd custom_nodes && git clone https://github.com/Fannovel16/comfy_controlnet_preprocessors
# !cd custom_nodes/comfy_controlnet_preprocessors && python install.py

# ComfyUI Manager
# !cd custom_nodes && git clone https://github.com/ltdrdata/ComfyUI-Manager.git

# ComfyUI Impact Pack - detección de caras, segmentación
# !cd custom_nodes && git clone https://github.com/ltdrdata/ComfyUI-Impact-Pack.git

# WAS Node Suite - nodos extra muy útiles
# !cd custom_nodes && git clone https://github.com/WASasquatch/was-node-suite-comfyui.git

# Efficiency Nodes - pipelines optimizados
# !cd custom_nodes && git clone https://github.com/jags111/efficiency-nodes-comfyui.git

# Instalar dependencias
# !pip install imageio imageio-ffmpeg opencv-python insightface onnxruntime -q

# ============================================================
# PASO 2 - CHECKPOINTS REALISTAS T2I (SDXL)
# ~45 GB este bloque
# ============================================================

# Juggernaut XL v9 - fotorrealismo top (6.5GB)
# !wget -c https://huggingface.co/RunDiffusion/Juggernaut-XL-v9/resolve/main/Juggernaut-XL_v9_RunDiffusionPhoto_v2.safetensors -P ./models/checkpoints/

# RealVisXL V4.0 - hiperrealismo (6.5GB)
# !wget -c https://huggingface.co/SG161222/RealVisXL_V4.0/resolve/main/RealVisXL_V4.0.safetensors -P ./models/checkpoints/

# DreamShaper XL - versátil retratos+fantasy (6.5GB)
# !wget -c https://huggingface.co/Lykon/dreamshaper-xl-1-0/resolve/main/DreamShaperXL_1.0.safetensors -P ./models/checkpoints/

# SDXL Base 1.0 oficial Stability (6.5GB)
# !wget -c https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors -P ./models/checkpoints/

# SDXL Refiner 1.0 - refinado final (6.5GB)
# !wget -c https://huggingface.co/stabilityai/stable-diffusion-xl-refiner-1.0/resolve/main/sd_xl_refiner_1.0.safetensors -P ./models/checkpoints/

# Realistic Vision V6 SD1.5 - fotos realistas ligero (2GB)
# !wget -c https://huggingface.co/SG161222/Realistic_Vision_V6.0_B1_noVAE/resolve/main/Realistic_Vision_V6.0_NV_B1.safetensors -P ./models/checkpoints/

# Deliberate v6 SD1.5 - versátil (2GB)
# !wget -c https://huggingface.co/XpucT/Deliberate/resolve/main/Deliberate_v6.safetensors -P ./models/checkpoints/

# CyberRealistic XL (6.5GB) - personas ultrarrealistas
# !wget -c https://huggingface.co/cyberdelia/CyberRealistic-XL/resolve/main/CyberRealisticXL_V1.safetensors -P ./models/checkpoints/

# ============================================================
# PASO 3 - TEXTO A VIDEO (AnimateDiff + SVD)
# ~16 GB este bloque
# ============================================================

# Motion Module SDXL (3.4GB)
# !wget -c https://huggingface.co/guoyww/animatediff/resolve/main/mm_sdxl_v10_beta.ckpt -P ./models/animatediff_models/

# Motion Module SD1.5 v2 (1.7GB)
# !wget -c https://huggingface.co/guoyww/animatediff/resolve/main/mm_sd_v15_v2.ckpt -P ./models/animatediff_models/

# AnimateDiff Lightning 4 pasos - ultrarrápido (1.7GB)
# !wget -c https://huggingface.co/ByteDance/AnimateDiff-Lightning/resolve/main/animatediff_lightning_4step_diffusers.safetensors -P ./models/animatediff_models/

# AnimateDiff Lightning 8 pasos - mejor calidad (1.7GB)
# !wget -c https://huggingface.co/ByteDance/AnimateDiff-Lightning/resolve/main/animatediff_lightning_8step_diffusers.safetensors -P ./models/animatediff_models/

# SVD XT - Stable Video Diffusion imagen a video (9.5GB)
# !wget -c https://huggingface.co/stabilityai/stable-video-diffusion-img2vid-xt/resolve/main/svd_xt.safetensors -P ./models/checkpoints/

# ============================================================
# PASO 4 - VAE
# ============================================================

# VAE SDXL fp16 fix (335MB)
# !wget -c https://huggingface.co/madebyollin/sdxl-vae-fp16-fix/resolve/main/sdxl_vae.safetensors -P ./models/vae/

# VAE SD1.5 MSE (335MB)
# !wget -c https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors -P ./models/vae/

# TAESD - previsualización rápida SD1.5 (4MB)
# !wget -c https://github.com/madebyollin/taesd/raw/main/taesd_decoder.pth -P ./models/vae/

# TAESDXL - previsualización rápida SDXL (4MB)
# !wget -c https://github.com/madebyollin/taesd/raw/main/taesdxl_decoder.pth -P ./models/vae/

# ============================================================
# PASO 5 - CLIP VISION (necesario para IPAdapter y SVD)
# ============================================================

# CLIP Vision G - SDXL y SVD (3.6GB)
# !wget -c https://huggingface.co/comfyanonymous/clip_vision_g/resolve/main/clip_vision_g.safetensors -P ./models/clip_vision/

# CLIP ViT-L - SD1.5 (890MB)
# !wget -c https://huggingface.co/openai/clip-vit-large-patch14/resolve/main/pytorch_model.bin -O ./models/clip_vision/clip_vit14.bin

# ============================================================
# PASO 6 - CONTROLNET SD1.5 (todos los útiles)
# ~7 GB este bloque
# ============================================================

# Canny - bordes
# !wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_canny_fp16.safetensors -P ./models/controlnet/

# Depth - profundidad 3D
# !wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11f1p_sd15_depth_fp16.safetensors -P ./models/controlnet/

# OpenPose - poses humanas
# !wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_openpose_fp16.safetensors -P ./models/controlnet/

# Lineart - dibujo a línea
# !wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_lineart_fp16.safetensors -P ./models/controlnet/

# Tile - upscaling con detalle
# !wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11u_sd15_tile_fp16.safetensors -P ./models/controlnet/

# Inpaint - rellenar zonas
# !wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors -P ./models/controlnet/

# Scribble - boceto a imagen
# !wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_scribble_fp16.safetensors -P ./models/controlnet/

# SoftEdge - bordes suaves
# !wget -c https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_softedge_fp16.safetensors -P ./models/controlnet/

# ============================================================
# PASO 7 - CONTROLNET SDXL
# ============================================================

# Canny SDXL (800MB)
# !wget -c https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-canny-rank256.safetensors -P ./models/controlnet/

# Depth SDXL (800MB)
# !wget -c https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-depth-rank256.safetensors -P ./models/controlnet/

# Sketch SDXL (800MB)
# !wget -c https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-sketch-rank256.safetensors -P ./models/controlnet/

# Recolor SDXL (800MB)
# !wget -c https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-recolor-rank256.safetensors -P ./models/controlnet/

# ============================================================
# PASO 8 - IPADAPTER (consistencia de cara/estilo)
# ============================================================

# IPAdapter SD1.5 base (290MB)
# !wget -c https://huggingface.co/h94/IP-Adapter/resolve/main/models/ip-adapter_sd15.safetensors -P ./models/ipadapter/

# IPAdapter SD1.5 Plus - mayor fidelidad (800MB)
# !wget -c https://huggingface.co/h94/IP-Adapter/resolve/main/models/ip-adapter-plus_sd15.safetensors -P ./models/ipadapter/

# IPAdapter SDXL base (800MB)
# !wget -c https://huggingface.co/h94/IP-Adapter/resolve/main/sdxl_models/ip-adapter_sdxl.safetensors -P ./models/ipadapter/

# IPAdapter SDXL Plus - mayor fidelidad (800MB)
# !wget -c https://huggingface.co/h94/IP-Adapter/resolve/main/sdxl_models/ip-adapter-plus_sdxl_vit-h.safetensors -P ./models/ipadapter/

# IPAdapter FaceID SDXL - caras consistentes (700MB)
# !wget -c https://huggingface.co/h94/IP-Adapter-FaceID/resolve/main/ip-adapter-faceid_sdxl.bin -P ./models/ipadapter/

# ============================================================
# PASO 9 - LORAS ÚTILES
# ============================================================

# LCM Lora SDXL - 4-8 pasos ultrarrápido (200MB)
# !wget -c https://huggingface.co/latent-consistency/lcm-lora-sdxl/resolve/main/pytorch_lora_weights.safetensors -O ./models/loras/lcm_lora_sdxl.safetensors

# LCM Lora SD1.5 (200MB)
# !wget -c https://huggingface.co/latent-consistency/lcm-lora-sdv1-5/resolve/main/pytorch_lora_weights.safetensors -O ./models/loras/lcm_lora_sd15.safetensors

# SDXL Offset Noise - mejora luces y sombras (74MB)
# !wget -c https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors -P ./models/loras/

# Detail Tweaker XL - más detalles en piel (200MB)
# !wget -c https://huggingface.co/Emirhan24/detail-tweaker-xl/resolve/main/detail-tweaker-xl.safetensors -P ./models/loras/

# ============================================================
# PASO 10 - UPSCALERS
# ============================================================

# 4x UltraSharp - el mejor para nitidez (67MB)
# !wget -c https://huggingface.co/lokCX/4x-Ultrasharp/resolve/main/4x-UltraSharp.pth -P ./models/upscale_models/

# RealESRGAN x4 plus (67MB)
# !wget -c https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth -P ./models/upscale_models/

# RealESRGAN x2 (67MB)
# !wget -c https://huggingface.co/sberbank-ai/Real-ESRGAN/resolve/main/RealESRGAN_x2.pth -P ./models/upscale_models/

# BSRGAN x4 - bueno para fotos reales (67MB)
# !wget -c https://github.com/cszn/BSRGAN/releases/download/v1.0/BSRGAN.pth -P ./models/upscale_models/

# ============================================================
# PASO 11 - EMBEDDINGS NEGATIVOS
# ============================================================

# EasyNegativeV2 (4MB)
# !wget -c https://huggingface.co/gsdf/Counterfeit-V3.0/resolve/main/embedding/EasyNegativeV2.safetensors -P ./models/embeddings/

# BadDream (2MB)
# !wget -c https://huggingface.co/Nerfgun3/bad_dream/resolve/main/bad_dream.pt -P ./models/embeddings/

# UnrealisticDream (2MB)
# !wget -c https://huggingface.co/Nerfgun3/bad_dream/resolve/main/unrealistic_dream.pt -P ./models/embeddings/

# ng_deepnegative SD1.5 (4MB)
# !wget -c https://huggingface.co/embed/negative/resolve/main/ng_deepnegative_v1_75t.pt -P ./models/embeddings/
# Out:
# Cloning into 'ComfyUI-AnimateDiff-Evolved'...
# remote: Enumerating objects: 3274, done.
# remote: Counting objects: 100% (1507/1507), done.
# remote: Compressing objects: 100% (348/348), done.
# remote: Total 3274 (delta 1264), reused 1166 (delta 1159), pack-reused 1767 (from 3)
# Receiving objects: 100% (3274/3274), 65.59 MiB | 23.31 MiB/s, done.
# Resolving deltas: 100% (2289/2289), done.
# Cloning into 'ComfyUI-VideoHelperSuite'...
# remote: Enumerating objects: 3345, done.
# remote: Counting objects: 100% (1597/1597), done.
# remote: Compressing objects: 100% (365/365), done.
# remote: Total 3345 (delta 1456), reused 1235 (delta 1230), pack-reused 1748 (from 3)
# Receiving objects: 100% (3345/3345), 793.81 KiB | 4.34 MiB/s, done.
# Resolving deltas: 100% (1972/1972), done.
# Cloning into 'ComfyUI-Advanced-ControlNet'...
# remote: Enumerating objects: 1407, done.
# remote: Counting objects: 100% (235/235), done.
# remote: Compressing objects: 100% (83/83), done.
# ...

# %% [markdown]
# ### Run ComfyUI with cloudflared (Recommended Way)

# %%
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch cloudflared (if it gets stuck here cloudflared is having issues)\n")

  p = subprocess.Popen(["cloudflared", "tunnel", "--url", "http://127.0.0.1:{}".format(port)], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
  for line in p.stderr:
    l = line.decode()
    if "trycloudflare.com " in l:
      print("This is the URL to access ComfyUI:", l[l.find("http"):], end='')
    #print(l, end='')


threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server

# %% [markdown]
# ### Run ComfyUI with localtunnel

# %%
# !npm install -g localtunnel

import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch localtunnel (if it gets stuck here localtunnel is having issues)\n")

  print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
  p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
  for line in p.stdout:
    print(line.decode(), end='')


threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server

# %% [markdown]
# ### Run ComfyUI with colab iframe (use only in case the previous way with localtunnel doesn't work)
#
# You should see the ui appear in an iframe. If you get a 403 error, it's your firefox settings or an extension that's messing things up.
#
# If you want to open it in another window use the link.
#
# Note that some UI features like live image previews won't work because the colab iframe blocks websockets.

# %%
import threading
import time
import socket
def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  from google.colab import output
  output.serve_kernel_port_as_iframe(port, height=1024)
  print("to open it in a window you can open this link here:")
  output.serve_kernel_port_as_window(port)

threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server
